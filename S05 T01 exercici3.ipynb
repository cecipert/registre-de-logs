# %% [markdown]
# # S05 T01 Expresiones regulares y parseo de logs
# ## Exercici 3
# Ir más allá..
#
# Este ejercicio debvería estar a continuación del notebook anterior.
# Sucede que lo cerré y no puedo volver a cargar los doscientos mil datos que tenía.
# Por lo tanto tomo los datos de geolocalización del Excercici 2 y los copio en este notebook.

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
# defino el dataframe con los datos del Exercici 2 
# en aquel caso tenía las IPs de 6 ciudades pero, pero dos de ellas coincidían
df = pd.DataFrame(
    {'City': ['Mountain View', 'Madrid', 'Tocina', 'New York'],
     'Country': ['United States', 'Spain', 'Spain', 'United States'],
     'Latitude': [37.422, 40.5005, 37.6025, 40.7616],
     'Longitude': [-122.084, -3.66739, -5.7307, -73.9985]})

df
# Out:
#             City        Country  Latitude  Longitude
# 0  Mountain View  United States   37.4220 -122.08400
# 1         Madrid          Spain   40.5005   -3.66739
# 2         Tocina          Spain   37.6025   -5.73070
# 3       New York  United States   40.7616  -73.99850

# %%
# obtengo el formato de los puntos que pide geopandas
gdf = gpd.GeoDataFrame(
    df, geometry=gpd.points_from_xy(df.Longitude, df.Latitude))

# %%
gdf
# Out:
#             City        Country  Latitude  Longitude  \
# 0  Mountain View  United States   37.4220 -122.08400
# 1         Madrid          Spain   40.5005   -3.66739
# 2         Tocina          Spain   37.6025   -5.73070
# 3       New York  United States   40.7616  -73.99850
#
#                       geometry
# 0  POINT (-122.08400 37.42200)
# 1    POINT (-3.66739 40.50050)
# 2    POINT (-5.73070 37.60250)
# 3   POINT (-73.99850 40.76160)

# %%
# armo el dibujo
ax = world[['continent', 'geometry']].plot(
    color='green', edgecolor='black', figsize=(15,15))
gdf.plot(ax=ax, color='red')

plt.show()
